# %% [markdown]
# # Load time series data from AWS S3 Bucket

# %%
pip install boto3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import boto3

# %%
bucket = "yash-tsaf-bucket"
file = "Electric_Production.csv"

# %% [markdown]
# Create a .env file and add calling parameters along with their key values

# %%
import os
from dotenv import load_dotenv
import boto3

#Load .env file
load_dotenv()

#Read Credentials
aws_access_key_id = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_access_key = os.getenv("AWS_SECRET_ACCESS_KEY")
region = os.getenv("AWS_DEFAULT_REGION")

#Create S3 Client
s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region
)

# %%
obj = s3.get_object(Bucket=bucket, Key=file)

# %%
obj
# Out:
# {'ResponseMetadata': {'RequestId': 'ZDYVABKZAV99PD9Y',
#   'HostId': 'D/dsr6zLhefs5TVWi4vq1dy5g3RjtEQP9ML7xTtMH7qrM/5O2dM/2Ay37f0BygN5UPKRS85FHRs=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'D/dsr6zLhefs5TVWi4vq1dy5g3RjtEQP9ML7xTtMH7qrM/5O2dM/2Ay37f0BygN5UPKRS85FHRs=',
#    'x-amz-request-id': 'ZDYVABKZAV99PD9Y',
#    'date': 'Wed, 19 Aug 2026 04:11:41 GMT',
#    'last-modified': 'Mon, 17 Aug 2026 03:52:18 GMT',
#    'etag': '"3e12f62edb6b15da2491c2045e8f6f84"',
#    'x-amz-checksum-crc64nvme': 'iXYCZ69v2f0=',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-server-side-encryption': 'AES256',
#    'accept-ranges': 'bytes',
#    'content-type': 'text/csv',
#    'content-length': '8008',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2026, 8, 17, 3, 52, 18, tzinfo=tzutc()),
#  'ContentLength': 8008,
#  'ETag': '"3e12f62edb6b15da2491c2045e8f6f84"',
#  'ChecksumCRC64NVME': 'iXYCZ69v2f0=',
# ...

# %%
type(obj)
# Out:
# dict

# %%
obj['Body']

# %%
df = pd.read_csv(obj['Body']) # 'Body' is a key that contains the actual data of the object. We can read it directly into a pandas DataFrame using pd.read_csv().

# %%
df.head()
# Out:
#          DATE    Value
# 0  01-01-1985  72.5052
# 1  02-01-1985  70.6720
# 2  03-01-1985  62.4502
# 3  04-01-1985  57.4714
# 4  05-01-1985  55.3151
